# %% [markdown]
# # Explore the diamonds data set

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from plotnine.data import diamonds
import math
import pandas as pd

# %%
from plotnine import (
    ggplot,
    xlab,
    ylab,
    aes,
    geom_histogram,
    geom_col,
    geom_map,
    geom_label,
    geom_bar,
    geom_boxplot,
    facet_grid,
    labs,
    guide_legend,
    guides,
    theme,
    element_text,
    element_line,
    element_rect,
    theme_xkcd,
    theme_set,
    theme_void,
    theme_538,
    coord_flip,
    scale_color_cmap,
    scale_x_discrete, 
    theme_bw,
    scale_fill_manual,
    facet_wrap,
    geom_point,
    ggtitle,
    geom_bin2d,
    scale_fill_gradient2,
    scale_fill_cmap,
    options
)

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %% [markdown]
# Check the structure of the dataset with either `str` from base R, `glimpse()`
# from `dplyr` package or with `skimr::skim_without_charts()` (package::function() is perhaps most commonly used form). Compare them and choose whichever you prefer.

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
from skimpy import skim
skim(diamonds)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types               Categories                                        │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓ ┏━━━━━━━━━━━━━━━━━━━━━━━┓                                │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃ ┃ Categorical Variables ┃                                │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩ ┡━━━━━━━━━━━━━━━━━━━━━━━┩                                │
# │ │ Number of rows    │ 53940  │ │ float64     │ 6     │ │ cut                   │                                │
# │ │ Number of columns │ 10     │ │ category    │ 3     │ │ color                 │                                │
# │ └───────────────────┴────────┘ │ int32       │ 1     │ │ clarity               │                                │
# ...

# %% [markdown]
# ## Histogram for diamonds
#
# Build a basic default (omit additional parameters) histogram of diamonds dataset
# using `ggplot()` and `geom_histogram()`.

# %%
(ggplot(diamonds) + 
    aes(x='carat') +
    geom_histogram())
# Out:
# C:\Stuff_snuff\myvenv\lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 142'. Pick better value with 'binwidth'.
# <Figure Size: (640 x 480)>

# %% [markdown]
# Copy your code from the previous chunk and play around with `binwidth` parameter
# of the `geom_histogram()` to find appropriate value in order to reveal the structure
# of the dataset:

# %%
(ggplot(diamonds) + 
    aes(x='carat') +
    geom_histogram(binwidth=0.6, fill='green')
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Save your best histogram to the object named `carat_hist` in the chunk below (
# uncomment the corresponding line):

# %%
carat_hist = (ggplot(diamonds) + 
    aes(x='carat') +
    geom_histogram(binwidth=0.6, fill='green')
    + theme_bw())

# %% [markdown]
# You can now print your histogram using just the object name `carat_hist`. Try
# it now below (you can just uncomment the line):

# %%
carat_hist
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Add fill colour to your saved histogram. Use `cut` as basis: add `aes()` to your
# `carat_hist` ggplot object with an appropriate parameter for `fill`:

# %%
(ggplot(diamonds) + 
    aes(x='carat', fill='cut') +
    geom_histogram(binwidth=0.6)
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Is this a good way to look at these two variables? - Not the best

# %% [markdown]
# Try finding a combination of colour/fill aesthetics and/or `facets` to show the interaction of these two variables (depth and cut) only using histogram, no other types of plot.
#
# You may some additional examples of using facets in ggplot2 book: see [https://ggplot2-book.org/getting-started.html#qplot-faceting](https://ggplot2-book.org/getting-started.html#qplot-faceting) for basic principles and [https://ggplot2-book.org/facet.html](https://ggplot2-book.org/facet.html) for an extended discussion.

# %%
(ggplot(diamonds, aes(x='depth',
                         fill='cut'))
    + facet_wrap('cut')
    + geom_histogram(binwidth=1.1,
                    colour="#D55E00",
                    alpha=0.7
                    )
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Repeat previous task for `carat` vs `color` and save this plot to the object called `carat_color_hist`:

# %%
(ggplot(diamonds, aes(x='carat',
                         fill='cut'))
    + facet_wrap('cut')
    + geom_histogram(binwidth=0.2,
                    color="#3b8c3e",
                    alpha=0.7
                    )
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# ## Scatter plots for diamonds
#
# Build a default basic scatter plot for `carat` vs `price`:

# %%
(ggplot(diamonds, aes(x='carat',y='price')) + geom_point(color='#c3eb54', size=0.1)
  + ggtitle('Scatter plot')
 + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Add `clarity` as a color aesthetic to the previous plot. You can either save the plot in the previous chunk as object and add ggplot functions to it to customize the plot, or you can reuse (copy and paste) the code from previous chunk and again add ggplot functions to it:

# %%
(ggplot(diamonds, aes(x='carat',y='price',color='clarity')) + geom_point(size=0.1)
    + ggtitle('Scatter plot')
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Try using the "large data approach" to the diamonds data set. Repeat the previous plot, but use `geom_hex()` instead of building a scatter plot. Copy all the other plot "layers" and options from the previous code chunk.

# %%
(ggplot(diamonds, aes(x='carat',y='price')) + geom_bin2d(binwidth=(.12,400))
    + ggtitle('hex-like, clarity facet')
    + scale_fill_cmap(cmap_name='magma')
    + facet_wrap('clarity')
    + theme_bw()
    + theme(figure_size=(16,16)))
# Out:
# <Figure Size: (1600 x 1600)>

# %%
(ggplot(diamonds, aes(x='carat',y='price', color='clarity')) + geom_bin2d(binwidth=(.16,800))
    + ggtitle('hex-like')
    + scale_fill_cmap(cmap_name='magma')
    + theme_bw()
    + theme(figure_size=(16,16)))
# Out:
# <Figure Size: (1600 x 1600)>

# %% [markdown]
# Does this plot look informative? What other technique can you use to view this data properly with geom_hex? You can try different approaches, but only provide your best option below. Save it as `carat_price_clarity_hex` (in the first line, or lines - if you are writing multi-line code for the plot) and print it out (in the last line of the chunk below).

# %%
diamonds['carat_less'] = [int(math.floor(n))+1 if n<=5 else 5 for n in diamonds['carat']]
carat_price_clarity_hex = (ggplot(diamonds, aes(x='carat',y='price')) + geom_bin2d(binwidth=(.08,1600))
    + ggtitle('hex-like')
    + facet_grid('clarity ~ carat_less', scales='free')
    + scale_fill_cmap(cmap_name='magma')
    + theme_bw()
    + theme(figure_size=(16,16)))

# %%
carat_price_clarity_hex
# Out:
# <Figure Size: (1600 x 1600)>

# %% [markdown]
# # Get some data from outside
#
# The line below uses `data.table::fread()`, which is the fastest way to load data from large csv files. For now we will only use this function from `data.table` package and will get to other functions next time.
#
# *Please note the syntax we use to call a function from package without loading it in its entirety.*

# %%
taxi = pd.read_csv("./data/yellow_tripdata_2016-03_21-27.csv")

# %% [markdown]
# ## What is the structure of the taxi data set? Use `str()`, `glimpse` or `skim`.

# %%
taxi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2649074 entries, 0 to 2649073
# Data columns (total 21 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   object
#  2   tpep_dropoff_datetime  object
#  3   passenger_count        int64
#  4   trip_distance          float64
#  5   pickup_longitude       float64
#  6   pickup_latitude        float64
#  7   RatecodeID             int64
#  8   store_and_fwd_flag     object
#  9   dropoff_longitude      float64
#  10  dropoff_latitude       float64
#  11  payment_type           int64
#  12  fare_amount            float64
#  13  extra                  float64
#  14  mta_tax                float64
#  15  tip_amount             float64
#  16  tolls_amount           float64
#  17  improvement_surcharge  float64
#  18  total_amount           float64
#  19  Day                    int64
#  20  Hour                   int64
# ...

# %%
taxi.head()
# Out:
#    VendorID  tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2016-03-25T10:13:14Z  2016-03-25T10:27:05Z                5
# 1         2  2016-03-25T10:13:14Z  2016-03-25T10:24:35Z                1
# 2         2  2016-03-25T10:13:14Z  2016-03-25T10:50:46Z                2
# 3         1  2016-03-25T10:13:15Z  2016-03-25T10:21:22Z                1
# 4         1  2016-03-25T10:13:15Z  2016-03-25T10:43:53Z                2
#
#    trip_distance  pickup_longitude  pickup_latitude  RatecodeID  \
# 0           1.92        -73.983742        40.780811           1
# 1           1.68        -73.995758        40.764381           1
# 2           8.74        -73.948990        40.788612           1
# 3           1.60        -73.974365        40.742847           1
# 4          10.70        -73.873055        40.774200           1
#
#   store_and_fwd_flag  dropoff_longitude  ...  payment_type  fare_amount  \
# ...

# %%
taxi.describe()
# Out:
#            VendorID  passenger_count  trip_distance  pickup_longitude  \
# count  2.649074e+06     2.649074e+06   2.649074e+06      2.649074e+06
# mean   1.532971e+00     1.677053e+00   6.478786e+00     -7.287210e+01
# std    4.989118e-01     1.318791e+00   5.130900e+03      8.960732e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00     -1.219332e+02
# 25%    1.000000e+00     1.000000e+00   1.000000e+00     -7.399194e+01
# 50%    2.000000e+00     1.000000e+00   1.720000e+00     -7.398194e+01
# 75%    2.000000e+00     2.000000e+00   3.210000e+00     -7.396754e+01
# max    2.000000e+00     9.000000e+00   8.330083e+06      0.000000e+00
#
#        pickup_latitude    RatecodeID  dropoff_longitude  dropoff_latitude  \
# count     2.649074e+06  2.649074e+06       2.649074e+06      2.649074e+06
# mean      4.014332e+01  1.042021e+00      -7.293265e+01      4.017782e+01
# std       4.936277e+00  6.392995e-01       8.713372e+00      4.800143e+00
# ...

# %%
skim(taxi)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                 Data Types                                                                │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                         │
# │ ┃ dataframe         ┃ Values  ┃ ┃ Column Type ┃ Count ┃                                                         │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                         │
# │ │ Number of rows    │ 2649074 │ │ float64     │ 12    │                                                         │
# │ │ Number of columns │ 21      │ │ int32       │ 6     │                                                         │
# │ └───────────────────┴─────────┘ │ string      │ 3     │                                                         │
# ...

# %% [markdown]
# ## Limit the data set to just certain hours of the day using dplyr verb `filter()` and save it as a new table object named ``taxi_6_12`.

# %%
taxi_6_12 = taxi.loc[(taxi['Hour']>=6) & (taxi['Hour'] <= 12)]

# %% [markdown]
# Check that you only have 6 to 12 hours in the `Hour` variable of `taxi_6_12` using `unique()` function.

# %%
taxi_6_12['Hour'].value_counts()
# Out:
# Hour
# 12    130776
# 11    123702
# 9     121494
# 10    120277
# 8     118215
# 7      91232
# 6      56066
# Name: count, dtype: int64

# %% [markdown]
# ## Create a histogram for Hours in `taxi` and save it as `g_hourly_trips`

# %%
g_hourly_trips = (ggplot(taxi) + 
    aes(x='Hour') +
    geom_histogram(bins=24, fill='green', color='orange', position='dodge')
    + theme_bw())

# %% [markdown]
# Print the plot from the chunk above by typing its name in the chunk below. Also use some plot style (your own, created above, or one of the styles from `ggthemes` or `ggpubr` packages):

# %%
g_hourly_trips
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(taxi_6_12) + 
    aes(x='Hour') +
    geom_histogram(bins=7, fill='green', color='orange', position='dodge')
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Notice if plotting the histogram for `taxi` and `taxi_6_12` takes the same time or whether one takes more time, than another.
#
# Try to add color/fill and/or facet using `as.factor(passenger_count)` (to use passenger count as colour group determinant, you need to specify it as a factor variable - we will discuss that extensively in lab 3) to both histograms (from full `taxi` and `taxi_6_12`) to reveal any connections between the variables. Leave the one that you think is the best:

# %%
taxi['passenger_count'] = taxi['passenger_count'].astype('category')
(ggplot(taxi) + 
    aes(x='Hour', fill='passenger_count') +
    geom_histogram(bins=24, color='#3b7a4c')
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %%
taxi_6_12['passenger_count'] = taxi_6_12['passenger_count'].astype('category')
(ggplot(taxi_6_12) + 
    aes(x='Hour', fill='passenger_count') +
    geom_histogram(bins=7, color='#3b7a4c')
    + theme_bw())
# Out:
# C:\Users\Peks\AppData\Local\Temp\ipykernel_1120\921248487.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <Figure Size: (640 x 480)>

# %% [markdown]
# ## Create histogram for total amount paid (just like in lab 1)
#
# But first check the range of the variable `total_amount` of the `taxi` table object using the `range()` function from lab 1:

# %%
taxi['total_amount'].describe()
# Out:
# count    2.516075e+06
# mean     1.403297e+01
# std      8.210510e+00
# min      4.310000e+00
# 25%      8.500000e+00
# 50%      1.175000e+01
# 75%      1.656000e+01
# max      4.913000e+01
# Name: total_amount, dtype: float64

# %%
taxi.hist(column='total_amount')
plt.show()

# %%
q_low  = taxi['total_amount'].quantile(0.01)
q_hi  = taxi['total_amount'].quantile(0.99)

taxi = taxi[(taxi['total_amount'] < q_hi) & (taxi['total_amount'] > q_low)]

# %%
q_low2  = taxi_6_12['total_amount'].quantile(0.01)
q_hi2  = taxi_6_12['total_amount'].quantile(0.99)

taxi_6_12 = taxi_6_12[(taxi_6_12['total_amount'] < q_hi2) & (taxi_6_12['total_amount'] > q_low2)]

q_low2  = taxi_6_12['fare_amount'].quantile(0.01)
q_hi2  = taxi_6_12['fare_amount'].quantile(0.99)

taxi_6_12 = taxi_6_12[(taxi_6_12['fare_amount'] < q_hi2) & (taxi_6_12['fare_amount'] > q_low2)]

# %%
taxi.hist(column='total_amount')
plt.show()

# %% [markdown]
# Are there any suspicious values? Before plotting the histogram use `filter()` to remove these values. Apply any plot theme to your liking.

# %%
(ggplot(taxi) + 
    aes(x='total_amount') +
    geom_histogram(bins=18, fill='lightgreen', color='orange', position='dodge')
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Create the same histogram as above, but now only for taxi rides that cost between 0 and 100 dollars. Adjust the bin width to reveal the structure of the data set:

# %%
(ggplot(taxi.loc[(taxi['total_amount']>=0) & (taxi['total_amount'] <= 100)]) + 
    aes(x='total_amount') +
    geom_histogram(bins=18, fill='lightgreen', color='orange', position='dodge')
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# ## Scatter plots
#
# Build a scatter plot for `fare_amount` vs `total_amount` from `taxi_6_12`. Measure the time it takes by enclosing the code for the plot in `system.time(print( _your_plot_code_or_name  ))` - see lab notes for examples. `system.time()` allows to measure the time, `print()` forces the plot to be printed. See what happens if you only use `system.time()` on your plot code without the `print()`.

# %%
# %%time
(ggplot(taxi_6_12, aes(x='total_amount',y='fare_amount')) + geom_point(color='#ba8534', size=0.5)
    + ggtitle('Scatter plot')
    + theme_bw())
# Out:
# CPU times: total: 0 ns
# Wall time: 4 ms
# <Figure Size: (640 x 480)>

# %% [markdown]
# Replace the scatter plot from above with hexbins geom [https://ggplot2.tidyverse.org/reference/geom_hex.html#examples](https://ggplot2.tidyverse.org/reference/geom_hex.html#examples). Also measure the plot printing time.

# %%
# %%time
(ggplot(taxi_6_12, aes(x='total_amount',y='fare_amount')) + geom_bin2d(bins=15)
    + ggtitle('hex-like')
    + scale_fill_cmap(cmap_name='YlOrBr')
    + theme_bw())
# Out:
# CPU times: total: 15.6 ms
# Wall time: 5 ms
# <Figure Size: (640 x 480)>

# %% [markdown]
# Repeat the code from above (apart from `system.time()` and `print()`) and try adding color/fill and/or facets using `passenger_count` and `Hour`. Only leave the code for the best combination of factors that you find.

# %%
# %%time
(ggplot(taxi_6_12, aes(x='total_amount',y='fare_amount')) + geom_bin2d(bins=8)
    + ggtitle('hex-like')
    + facet_grid('Hour ~ .', space='free')
    + scale_fill_cmap(cmap_name='copper')
    + theme_bw()
    + theme(figure_size=(16,16)))
# Out:
# CPU times: total: 15.6 ms
# Wall time: 9 ms
# <Figure Size: (1600 x 1600)>

# %% [markdown]
# # Boxplots practice
#
# You may know that there exists a difference in wages for men and women called gender gap.
#
# In Russia we have Russian Longitudinal Monitoring Survey - HSE (RLMS-HSE) dataset that may
# be used as a first step to look into the gender gap.
#
# Please, download the dataset of wave 29 (2020) from the site [https://www.hse.ru/rlms/spss](https://www.hse.ru/rlms/spss), - you need representative dataset by individuals. You will be asked for registration, but that is just to send you some code via an email. Place `r29i_os_42.sav` file into the `./data/` folder.
#
# Use `haven` package to read the corresponding SPSS file.

# %%
rlms = pd.read_spss('./data/r29i_os_61.sav')

# %% [markdown]
# Try to use some technique like `str` or `glimpse` to look into the data. We suppose that
# in this case a simple `head` function is perhaps most useful.

# %%
rlms.head()
# Out:
#    idind      yid_i  yredid_i    yid_h      xid_i    xid_h      wid_i  \
# 0    3.0  1001201.0  102001.0  10012.0  1001201.0  10012.0  1001201.0
# 1    7.0  1000301.0  101701.0  10003.0  1000301.0  10003.0  1000301.0
# 2    9.0  1000401.0  101801.0  10004.0  1000401.0  10004.0        NaN
# 3   36.0  1002401.0  102601.0  10024.0  1002401.0  10024.0  1002401.0
# 4   60.0  1004702.0  104002.0  10047.0  1004702.0  10047.0  1004702.0
#
#      wid_h      vid_i    vid_h  ...  ym109  ym111  ys1.1  ys1.2  ys2  ys3  \
# 0  10012.0  1001201.0  10012.0  ...    NaN    NaN    NaN    NaN  NaN  NaN
# 1  10003.0  1000301.0  10003.0  ...    NaN    NaN    NaN    NaN  NaN  NaN
# 2      NaN  1000401.0  10004.0  ...    NaN    NaN    NaN    NaN  NaN  NaN
# 3  10024.0        NaN      NaN  ...    NaN    NaN    NaN    NaN  NaN  NaN
# 4  10047.0  1004702.0  10047.0  ...    NaN    NaN    NaN    NaN  NaN  NaN
#
#    ys4  ys5  ys6  ys7
# 0  NaN  NaN  NaN  NaN
# 1  NaN  NaN  NaN  NaN
# 2  NaN  NaN  NaN  NaN
# ...

# %%
rlms.describe()
# Out:
#               idind         yid_i       yredid_i         yid_h         xid_i  \
# count  12120.000000  1.212000e+04   12120.000000  1.212000e+04  1.072200e+04
# mean   38523.022772  1.332527e+08  330890.525990  1.332527e+06  1.242429e+08
# std    17202.371919  2.473922e+08  191376.490345  2.473922e+06  2.317087e+08
# min        3.000000  1.000301e+06     501.000000  1.000300e+04  1.000301e+06
# 25%    27162.750000  4.802995e+07  168601.750000  4.802995e+05  4.801760e+07
# 50%    41257.500000  8.401565e+07  327053.000000  8.401565e+05  7.701400e+07
# 75%    52756.250000  1.360147e+08  488726.750000  1.360147e+06  1.350094e+08
# max    60476.000000  1.429002e+09  678802.000000  1.429002e+07  1.429002e+09
#
#               xid_h         wid_i         wid_h         vid_i         vid_h  \
# count  1.072200e+04  9.879000e+03  9.879000e+03  9.263000e+03  9.263000e+03
# mean   1.242429e+06  1.142645e+08  1.142645e+06  1.060195e+08  1.060195e+06
# ...

# %% [markdown]
# Now download the codebook from [https://www.hse.ru/rlms/code](https://www.hse.ru/rlms/code) and find which
# variables describe sex and wage. Use `dplyr::select()` to select these variables from the dataset.
# Then use whichever you prefer to rename these variables to `sex` and `wage`. Hint: you may rename variables while doing `select()`.
#
# Save the result into the variable named rlms_sw

# %%
rlms_sw = rlms[['yh5', 'yj13.2']]

# %% [markdown]
# Now we shall fix the data format to make sure R understands it well. Just uncomment the lines of code below.

# %%
rlms_sw.dropna(inplace=True)
# Out:
# C:\Users\Peks\AppData\Local\Temp\ipykernel_1120\1934642763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
rlms_sw = rlms_sw[~rlms_sw['yj13.2'].str.contains("[a-zA-Z]").fillna(False)]

# %%
rlms_sw = rlms_sw[pd.to_numeric(rlms_sw['yj13.2'], errors='coerce').notnull()]

# %%
rlms_sw['yj13.2'] = np.array(rlms_sw['yj13.2'],dtype='float64')

# %%
rlms_sw['yj13.2'].value_counts()
# Out:
# yj13.2
# 30000.0    439
# 20000.0    377
# 25000.0    310
# 40000.0    274
# 15000.0    239
#           ...
# 83000.0      1
# 8400.0       1
# 28950.0      1
# 4800.0       1
# 63000.0      1
# Name: count, Length: 249, dtype: int64

# %% [markdown]
# Now make a boxplot that illustrates the gender gap (use geom_boxplot). To start use barebone `geom_boxplot` without any additions.

# %%
(ggplot(rlms_sw, aes(x='yh5',y='yj13.2'))
    + geom_boxplot()
    + ggtitle('gender gap')
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Do you find this chart informative?
#
# **TOO MUCH OUTLIERS!!!**
#
# Now filter the dataset so it shows some real difference. Choose the cutoff value that you prefer and save the result
# into the variable `rlms_sw_filtered`.

# %%
rlms_sw_filtered = rlms_sw.loc[(rlms_sw['yj13.2']<=80000)]

# %% [markdown]
# Copy the code for the boxplot and try to use it on new data.

# %%
(ggplot(rlms_sw_filtered, aes(x='yh5',y='yj13.2'))
    + geom_boxplot()
    + ggtitle('gender gap')
    + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# We may see some difference now, aren't we? Now add some styling, change axis titles by using `xlab`, `ylab` functions, change the title with `ggtitle()`, or apply any style you prefer. Save the chart into the variable named `rlms_gg_plot` (gg goes for gender gap).

# %% [markdown]
# Print the plot here (just uncomment the code line below)

# %%
rlms_gg_plot = (ggplot(rlms_sw_filtered, aes(x='yh5',y='yj13.2', color='yh5'))
    + geom_boxplot()
    + ggtitle('gender gap')
    + theme_bw()
    + xlab('sex') 
    + ylab('money'))

# %%
rlms_gg_plot
# Out:
# <Figure Size: (640 x 480)>

# %% [markdown]
# Now use `summarize()` to create the dataset with two rows and two columns: the first column should go for `sex` and the second should contain the average value for `wage` for the specified `sex`. Hint: use `na.rm` while applying `mean()` to omit NA values. Save the result into the dataframe called `rlms_wage_summary`.

# %%
rlms_wage_summary = rlms_sw_filtered.groupby('yh5').mean()

# %%
rlms_wage_summary.columns = ['wage']

# %%
rlms_wage_summary
# Out:
#                  wage
# yh5
# ЖЕНСКИЙ  24410.719368
# МУЖСКОЙ  32362.312335

# %%
# (ggplot(rlms_sw_filtered, aes(x='yh5',y='yj13.2', color='yh5'))
#     + geom_boxplot()
#     + ggtitle('gender gap')
#     + theme_bw()
#     + xlab('sex') 
#     + ylab('money')
#     + geom_label(data = rlms_wage_summary, mapping = aes(label='wage')))

# %% [markdown]
# **I see that it may be probable that gender gap in terms of perception of wage exists for social groups of parameters of research dataset**
#
# **Might be comprehensive to explore distribution of wage by gender by quartile ranges using median and check how the gap behave among income stratifications, also might be interesting to compare with boxplots of life expectancy and health parameters**
